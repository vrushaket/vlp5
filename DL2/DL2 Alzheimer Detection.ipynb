# %% [markdown]
# # LIBRARIES

# %%
# !pip install opendatasets
import opendatasets as od
od.download("https://www.kaggle.com/datasets/sachinkumar413/alzheimer-mri-dataset")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vrushaketchaudhari
# Your Kaggle Key: ··········
# Downloading alzheimer-mri-dataset.zip to ./alzheimer-mri-dataset
# 100%|██████████| 28.0M/28.0M [00:02<00:00, 12.5MB/s]

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
from tensorflow import keras
from keras import layers
import matplotlib.image as img
# %matplotlib inline

# %% [markdown]
# # DATA LOAD

# %%
# !pip install split-folders
import splitfolders
splitfolders.ratio('alzheimer-mri-dataset/Dataset', output="output", seed=1345, ratio=(.8, 0.1,0.1))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1
# Copying files: 6400 files [00:00, 8602.16 files/s]

# %%
IMG_HEIGHT = 128
IMG_WIDTH = 128
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/train",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/test",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
"./output/val",
seed=123,
image_size=(IMG_HEIGHT, IMG_WIDTH),
batch_size=64
)
# Out:
# Found 5119 files belonging to 4 classes.
# Found 642 files belonging to 4 classes.
# Found 639 files belonging to 4 classes.

# %%
class_names = train_ds.class_names
print(class_names)
train_ds
# Out:
# ['Mild_Demented', 'Moderate_Demented', 'Non_Demented', 'Very_Mild_Demented']
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# # EXAMPLE IMAGE

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
size = [896,64,3200,2240]
ax.bar(class_names,size)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # MODEL

# %%
model = keras.models.Sequential()
model.add(keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(IMG_HEIGHT,IMG_WIDTH, 3)))
model.add(keras.layers.Conv2D(filters=16,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))


model.add(keras.layers.Conv2D(filters=32,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.20))

model.add(keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding='same',activation='relu',kernel_initializer="he_normal"))
model.add(keras.layers.MaxPooling2D(pool_size=(2,2)))

model.add(keras.layers.Dropout(0.25))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(128,activation="relu",kernel_initializer="he_normal"))
model.add(keras.layers.Dense(64,"relu"))
model.add(keras.layers.Dense(4,"softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer = "Adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 128, 128, 3)       0
#
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 32, 32, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 64)        0
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 128)               2097280
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 2,129,380
# Trainable params: 2,129,380
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(train_ds,validation_data=val_ds,epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 80/80 [==============================] - 18s 59ms/step - loss: 1.0945 - accuracy: 0.5101 - val_loss: 0.8995 - val_accuracy: 0.5634
# Epoch 2/100
# 80/80 [==============================] - 4s 49ms/step - loss: 0.8873 - accuracy: 0.5847 - val_loss: 0.8647 - val_accuracy: 0.5884
# Epoch 3/100
# 80/80 [==============================] - 5s 56ms/step - loss: 0.8081 - accuracy: 0.6316 - val_loss: 0.6932 - val_accuracy: 0.7027
# Epoch 4/100
# 80/80 [==============================] - 4s 46ms/step - loss: 0.6569 - accuracy: 0.7183 - val_loss: 0.5924 - val_accuracy: 0.7981
# Epoch 5/100
# 80/80 [==============================] - 3s 39ms/step - loss: 0.5312 - accuracy: 0.7808 - val_loss: 0.4615 - val_accuracy: 0.8372
# Epoch 6/100
# 80/80 [==============================] - 3s 42ms/step - loss: 0.4158 - accuracy: 0.8328 - val_loss: 0.2998 - val_accuracy: 0.9124
# Epoch 7/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2962 - accuracy: 0.8832 - val_loss: 0.2416 - val_accuracy: 0.9296
# Epoch 8/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.2816 - accuracy: 0.8914 - val_loss: 0.1898 - val_accuracy: 0.9562
# Epoch 9/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.2109 - accuracy: 0.9209 - val_loss: 0.1509 - val_accuracy: 0.9577
# Epoch 10/100
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1830 - accuracy: 0.9346 - val_loss: 0.2202 - val_accuracy: 0.9171
# Epoch 11/100
# 80/80 [==============================] - 4s 48ms/step - loss: 0.1614 - accuracy: 0.9410 - val_loss: 0.1095 - val_accuracy: 0.9656
# Epoch 12/100
# 80/80 [==============================] - 4s 50ms/step - loss: 0.1367 - accuracy: 0.9496 - val_loss: 0.1186 - val_accuracy: 0.9703
# Epoch 13/100
# 80/80 [==============================] - 5s 56ms/step - loss: 0.1038 - accuracy: 0.9654 - val_loss: 0.1011 - val_accuracy: 0.9703
# Epoch 14/100
# 80/80 [==============================] - 4s 47ms/step - loss: 0.0991 - accuracy: 0.9627 - val_loss: 0.0700 - val_accuracy: 0.9828
# Epoch 15/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0878 - accuracy: 0.9682 - val_loss: 0.0630 - val_accuracy: 0.9828
# Epoch 16/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.1068 - accuracy: 0.9600 - val_loss: 0.0809 - val_accuracy: 0.9781
# Epoch 17/100
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0952 - accuracy: 0.9676 - val_loss: 0.0455 - val_accuracy: 0.9875
# Epoch 18/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0878 - accuracy: 0.9701 - val_loss: 0.0773 - val_accuracy: 0.9718
# Epoch 19/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0678 - accuracy: 0.9777 - val_loss: 0.0469 - val_accuracy: 0.9906
# Epoch 20/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0617 - accuracy: 0.9771 - val_loss: 0.0400 - val_accuracy: 0.9890
# Epoch 21/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0607 - accuracy: 0.9771 - val_loss: 0.0506 - val_accuracy: 0.9828
# Epoch 22/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0908 - accuracy: 0.9685 - val_loss: 0.0533 - val_accuracy: 0.9859
# Epoch 23/100
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0535 - accuracy: 0.9820 - val_loss: 0.0329 - val_accuracy: 0.9953
# Epoch 24/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0381 - accuracy: 0.9857 - val_loss: 0.0441 - val_accuracy: 0.9844
# Epoch 25/100
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0472 - accuracy: 0.9840 - val_loss: 0.0324 - val_accuracy: 0.9890
# Epoch 26/100
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0435 - accuracy: 0.9840 - val_loss: 0.0870 - val_accuracy: 0.9624
# Epoch 27/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0504 - accuracy: 0.9826 - val_loss: 0.0388 - val_accuracy: 0.9937
# Epoch 28/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0433 - accuracy: 0.9857 - val_loss: 0.0398 - val_accuracy: 0.9859
# Epoch 29/100
# 80/80 [==============================] - 4s 44ms/step - loss: 0.0375 - accuracy: 0.9873 - val_loss: 0.0604 - val_accuracy: 0.9781
# Epoch 30/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0505 - accuracy: 0.9834 - val_loss: 0.0359 - val_accuracy: 0.9890
# Epoch 31/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0294 - accuracy: 0.9896 - val_loss: 0.0307 - val_accuracy: 0.9937
# Epoch 32/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0335 - accuracy: 0.9887 - val_loss: 0.0216 - val_accuracy: 0.9937
# Epoch 33/100
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0314 - accuracy: 0.9896 - val_loss: 0.0314 - val_accuracy: 0.9890
# Epoch 34/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0223 - accuracy: 0.9924 - val_loss: 0.0537 - val_accuracy: 0.9875
# Epoch 35/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0444 - accuracy: 0.9834 - val_loss: 0.0232 - val_accuracy: 0.9953
# Epoch 36/100
# 80/80 [==============================] - 3s 34ms/step - loss: 0.0352 - accuracy: 0.9879 - val_loss: 0.0503 - val_accuracy: 0.9828
# Epoch 37/100
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0315 - accuracy: 0.9902 - val_loss: 0.0275 - val_accuracy: 0.9937
# Epoch 38/100
# 80/80 [==============================] - 3s 28ms/step - loss: 0.0432 - accuracy: 0.9846 - val_loss: 0.0304 - val_accuracy: 0.9890
# Epoch 39/100
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0284 - accuracy: 0.9891 - val_loss: 0.0219 - val_accuracy: 0.9953
# Epoch 40/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0306 - accuracy: 0.9889 - val_loss: 0.0205 - val_accuracy: 0.9937
# Epoch 41/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0198 - accuracy: 0.9926 - val_loss: 0.0299 - val_accuracy: 0.9953
# Epoch 42/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0266 - accuracy: 0.9912 - val_loss: 0.0331 - val_accuracy: 0.9906
# Epoch 43/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0248 - accuracy: 0.9914 - val_loss: 0.0238 - val_accuracy: 0.9922
# Epoch 44/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0318 - accuracy: 0.9895 - val_loss: 0.0309 - val_accuracy: 0.9937
# Epoch 45/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0243 - accuracy: 0.9914 - val_loss: 0.0287 - val_accuracy: 0.9922
# Epoch 46/100
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0268 - accuracy: 0.9924 - val_loss: 0.0364 - val_accuracy: 0.9875
# Epoch 47/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0276 - accuracy: 0.9908 - val_loss: 0.0322 - val_accuracy: 0.9953
# Epoch 48/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0241 - accuracy: 0.9920 - val_loss: 0.0229 - val_accuracy: 0.9953
# Epoch 49/100
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0327 - accuracy: 0.9881 - val_loss: 0.0373 - val_accuracy: 0.9906
# Epoch 50/100
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0200 - accuracy: 0.9937 - val_loss: 0.0170 - val_accuracy: 0.9969
# Epoch 51/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0301 - accuracy: 0.9906 - val_loss: 0.0273 - val_accuracy: 0.9922
# Epoch 52/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.0197 - val_accuracy: 0.9984
# Epoch 53/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0295 - accuracy: 0.9895 - val_loss: 0.0199 - val_accuracy: 0.9953
# Epoch 54/100
# 80/80 [==============================] - 3s 37ms/step - loss: 0.0230 - accuracy: 0.9922 - val_loss: 0.0211 - val_accuracy: 0.9969
# Epoch 55/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0229 - val_accuracy: 0.9969
# Epoch 56/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0253 - accuracy: 0.9904 - val_loss: 0.0419 - val_accuracy: 0.9781
# Epoch 57/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0332 - accuracy: 0.9867 - val_loss: 0.0326 - val_accuracy: 0.9937
# Epoch 58/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0234 - accuracy: 0.9924 - val_loss: 0.0340 - val_accuracy: 0.9937
# Epoch 59/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0398 - accuracy: 0.9863 - val_loss: 0.0392 - val_accuracy: 0.9906
# Epoch 60/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0241 - accuracy: 0.9926 - val_loss: 0.0257 - val_accuracy: 0.9937
# Epoch 61/100
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0185 - accuracy: 0.9930 - val_loss: 0.0318 - val_accuracy: 0.9922
# Epoch 62/100
# 80/80 [==============================] - 3s 36ms/step - loss: 0.0257 - accuracy: 0.9906 - val_loss: 0.0356 - val_accuracy: 0.9937
# Epoch 63/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.0263 - val_accuracy: 0.9937
# Epoch 64/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0266 - accuracy: 0.9920 - val_loss: 0.0396 - val_accuracy: 0.9906
# Epoch 65/100
# 80/80 [==============================] - 3s 39ms/step - loss: 0.0177 - accuracy: 0.9930 - val_loss: 0.0319 - val_accuracy: 0.9922
# Epoch 66/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.0158 - val_accuracy: 0.9984
# Epoch 67/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0171 - accuracy: 0.9937 - val_loss: 0.0181 - val_accuracy: 0.9969
# Epoch 68/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0243 - val_accuracy: 0.9953
# Epoch 69/100
# 80/80 [==============================] - 4s 43ms/step - loss: 0.0295 - accuracy: 0.9900 - val_loss: 0.0259 - val_accuracy: 0.9969
# Epoch 70/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0110 - accuracy: 0.9967 - val_loss: 0.0303 - val_accuracy: 0.9953
# Epoch 71/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.0163 - val_accuracy: 0.9969
# Epoch 72/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0120 - val_accuracy: 0.9969
# Epoch 73/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0176 - accuracy: 0.9936 - val_loss: 0.0194 - val_accuracy: 0.9969
# Epoch 74/100
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0197 - accuracy: 0.9930 - val_loss: 0.0155 - val_accuracy: 0.9969
# Epoch 75/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0204 - accuracy: 0.9930 - val_loss: 0.0131 - val_accuracy: 0.9953
# Epoch 76/100
# 80/80 [==============================] - 3s 29ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0272 - val_accuracy: 0.9937
# Epoch 77/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0173 - accuracy: 0.9945 - val_loss: 0.0152 - val_accuracy: 0.9969
# Epoch 78/100
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0199 - accuracy: 0.9926 - val_loss: 0.0149 - val_accuracy: 0.9984
# Epoch 79/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0098 - accuracy: 0.9971 - val_loss: 0.0112 - val_accuracy: 0.9984
# Epoch 80/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0150 - accuracy: 0.9951 - val_loss: 0.0097 - val_accuracy: 0.9984
# Epoch 81/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0162 - accuracy: 0.9951 - val_loss: 0.0212 - val_accuracy: 0.9969
# Epoch 82/100
# 80/80 [==============================] - 4s 45ms/step - loss: 0.0118 - accuracy: 0.9943 - val_loss: 0.0141 - val_accuracy: 0.9969
# Epoch 83/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0242 - accuracy: 0.9912 - val_loss: 0.0181 - val_accuracy: 0.9969
# Epoch 84/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.0158 - val_accuracy: 0.9953
# Epoch 85/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.0117 - val_accuracy: 0.9984
# Epoch 86/100
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0326 - accuracy: 0.9896 - val_loss: 0.0461 - val_accuracy: 0.9844
# Epoch 87/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0272 - accuracy: 0.9895 - val_loss: 0.0180 - val_accuracy: 0.9953
# Epoch 88/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0171 - accuracy: 0.9949 - val_loss: 0.0085 - val_accuracy: 0.9969
# Epoch 89/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0122 - accuracy: 0.9969 - val_loss: 0.0143 - val_accuracy: 0.9969
# Epoch 90/100
# 80/80 [==============================] - 4s 46ms/step - loss: 0.0164 - accuracy: 0.9941 - val_loss: 0.0121 - val_accuracy: 0.9969
# Epoch 91/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0099 - accuracy: 0.9961 - val_loss: 0.0141 - val_accuracy: 0.9969
# Epoch 92/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0113 - val_accuracy: 0.9984
# Epoch 93/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0134 - accuracy: 0.9943 - val_loss: 0.0211 - val_accuracy: 0.9969
# Epoch 94/100
# 80/80 [==============================] - 3s 32ms/step - loss: 0.0089 - accuracy: 0.9977 - val_loss: 0.0464 - val_accuracy: 0.9844
# Epoch 95/100
# 80/80 [==============================] - 3s 38ms/step - loss: 0.0119 - accuracy: 0.9961 - val_loss: 0.0115 - val_accuracy: 0.9969
# Epoch 96/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0242 - val_accuracy: 0.9937
# Epoch 97/100
# 80/80 [==============================] - 2s 30ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0132 - val_accuracy: 0.9953
# Epoch 98/100
# 80/80 [==============================] - 3s 31ms/step - loss: 0.0103 - accuracy: 0.9961 - val_loss: 0.0129 - val_accuracy: 0.9953
# Epoch 99/100
# 80/80 [==============================] - 3s 30ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.0152 - val_accuracy: 0.9953
# Epoch 100/100
# 80/80 [==============================] - 2s 29ms/step - loss: 0.0142 - accuracy: 0.9957 - val_loss: 0.0171 - val_accuracy: 0.9953

# %% [markdown]
# # Plot the result

# %%
get_ac = hist.history['accuracy']
get_los = hist.history['loss']
val_acc = hist.history['val_accuracy']
val_loss = hist.history['val_loss']

# %%
epochs = range(len(get_ac))
plt.plot(epochs, get_ac, 'g', label='Accuracy of Training data')
plt.plot(epochs, get_los, 'r', label='Loss of Training data')
plt.title('Training data accuracy and loss')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_ac, 'g', label='Accuracy of Training Data')
plt.plot(epochs, val_acc, 'r', label='Accuracy of Validation Data')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, get_los, 'g', label='Loss of Training Data')
plt.plot(epochs, val_loss, 'r', label='Loss of Validation Data')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()
plt.show()

# %% [markdown]
# # Predictions

# %%
loss, accuracy = model.evaluate(test_ds)
# Out:
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0169 - accuracy: 0.9922

# %%
plt.figure(figsize=(20, 20))
for images, labels in test_ds.take(1):
    for i in range(16):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        predictions = model.predict(tf.expand_dims(images[i], 0))
        score = tf.nn.softmax(predictions[0])
        if(class_names[labels[i]]==class_names[np.argmax(score)]):
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'green'})
            
        else:
            plt.title("Actual: "+class_names[labels[i]])
            plt.ylabel("Predicted: "+class_names[np.argmax(score)],fontdict={'color':'red'})
        plt.gca().axes.yaxis.set_ticklabels([])        
        plt.gca().axes.xaxis.set_ticklabels([])
# Out:
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
